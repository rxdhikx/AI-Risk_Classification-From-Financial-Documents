# %% [markdown]
# ### Uncleaned Data

# %%
import pandas as pd
df = pd.read_csv("/Users/rravindra0463/Desktop/ai_proj/venv/output/Results_QTR2.csv")
df.head(20)
# Out:
#                                              filename  \
# 0   20230417_10-K_edgar_data_1850051_0001104659-23...
# 1   20230417_10-K_edgar_data_1850051_0001104659-23...
# 2   20230417_10-K_edgar_data_1850051_0001104659-23...
# 3   20230417_10-K_edgar_data_1850051_0001104659-23...
# 4   20230417_10-K_edgar_data_1850051_0001104659-23...
# 5   20230522_10-K_edgar_data_797721_0000950170-23-...
# 6   20230522_10-K_edgar_data_797721_0000950170-23-...
# 7   20230522_10-K_edgar_data_797721_0000950170-23-...
# 8   20230417_10-K_edgar_data_1792581_0001558370-23...
# 9   20230417_10-K_edgar_data_1792581_0001558370-23...
# 10  20230417_10-K_edgar_data_1792581_0001558370-23...
# 11  20230417_10-K_edgar_data_1792581_0001558370-23...
# 12  20230417_10-K_edgar_data_1792581_0001558370-23...
# 13  20230417_10-K_edgar_data_1792581_0001558370-23...
# 14  20230417_10-K_edgar_data_1792581_0001558370-23...
# 15  20230417_10-K_edgar_data_1792581_0001558370-23...
# ...

# %%
content1 = df.loc[1, 'Item1A']
content2 = df.loc[1, 'filename']

print(f'This is content2: {content2}')
print(f'This is content1: {content1}')
# Out:
# This is content2: 20230417_10-K_edgar_data_1850051_0001104659-23-046201.txt
# This is content1: . risk factors. an investment in our securities involves a high degree of risk. you should consider carefully all of the risks described below, together with the other information contained in this form 10-k, before making a decision to invest in our securities. if any of the following events occur, our business, financial condition and operating results may be materially adversely affected. in that event, the trading price of our securities could decline, and you could lose all or part of your investment. the risks include the following: we are a recently incorporated company with no operating history and no revenues, and you have no basis on which to evaluate our ability to achieve our business objective.
#  20
#
# table of contents
# ...

# %%
# Random Check
filename = "20230417_10-K_edgar_data_1843388_0001628280-23-011773.txt"

# Locate the row and display the 'item1a' column data
item1a_data = df.loc[df['filename'] == filename, 'Item1A'].values
if item1a_data.size > 0:
    print(item1a_data[0])
else:
    print("No data found") #because no AI related keyword present
# Out:
# No data found
